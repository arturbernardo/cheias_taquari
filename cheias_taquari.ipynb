# %% [markdown]
# <a href="https://colab.research.google.com/github/arturbernardo/cheias_taquari/blob/main/cheias_taquari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

dateparse = lambda dates: [datetime.strptime(d, '%d/%m/%Y') for d in dates]

df = pd.read_csv('/content/cheias_taquari.csv',
                 decimal=',',
                 parse_dates=['data'],
                 date_parser=dateparse,
                 sep = ',',
                 dtype={
                          "cota": float
                      }
                 )
df
# Out:
# <ipython-input-18-fee378911103>:6: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv('/content/cheias_taquari.csv',
#          data   cota Unnamed: 2
# 0  1940-07-18  26.40        NaN
# 1  1941-05-06  28.65        NaN
# 2  1941-11-18  25.93        NaN
# 3  1942-05-20  23.90        NaN
# 4  1946-01-27  27.40        NaN
# 5  1954-09-23  27.35        NaN
# 6  1956-04-06  28.86        NaN
# 7  1965-08-22  26.40        NaN
# 8  1967-09-20  26.33        NaN
# 9  1982-06-29  25.40        NaN
# 10 1983-07-10  24.75        NaN
# 11 1988-09-15  24.25        NaN
# 12 1989-09-12  25.20        NaN
# 13 1989-09-25  25.89        NaN
# 14 1990-06-02  26.64        NaN
# 15 1990-10-16  22.10        NaN
# 16 1992-05-28  25.35        NaN
# 17 1997-08-05  25.60        NaN
# 18 2000-10-13  23.80        NaN
# ...

# %%
df_filtered = df[df['cota'] > 25]
df_filtered

# %%
import altair as alt

chart = alt.Chart(df_filtered).mark_line().encode(
    x = 'data:T',
    y = 'cota'
)

chart
# Out:
# alt.Chart(...)
